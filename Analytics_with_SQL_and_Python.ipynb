# %% [markdown]
# <a href="https://colab.research.google.com/github/add54/-docs-Dwyer-G.-Aggarwal-S.-Stouffer-J.---Flask-Building-Python-Web-Services---2017.pdf-/blob/master/Analytics_with_SQL_and_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fifa data.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...  ...  52+2  63+2
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...  ...  53+3  61+3
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...  ...  46+3  61+3
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...  ...   NaN   NaN
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
#
# [5 rows x 104 columns]

# %%
fifa.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
#fifa.mean()
for col in fifa.columns: 
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color="g")
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)
player_salary
# Out:
#              short_name  wage_eur
# 0              L. Messi    565000
# 4             E. Hazard    470000
# 1     Cristiano Ronaldo    405000
# 22         A. Griezmann    370000
# 5          K. De Bruyne    370000
# ...                 ...       ...
# 1612        A. Zamorado         0
# 1611            A. Vera         0
# 1610        M. Fagundez         0
# 1609          G. Ichazo         0
# 3053      F. Kudryashov         0
#
# [18278 rows x 2 columns]

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color=["blue","green","red","pink","orange"])
plt.show()

# %%
fifa['nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Germany=fifa[fifa['nationality']=='Germany']
Germany.head(10)
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...  ...   NaN   NaN
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...  ...  55+3  64+3
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...  ...  84+3  78+3
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...  ...  52+2  61+2
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...  ...  78+3  81+3
# 70      189596  https://sofifa.com/player/189596/thomas-muller...  ...  62+3  67+3
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...  ...  83+2  75+2
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...  ...  54+2  62+2
#
# [10 rows x 104 columns]

# %%
Germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...  ...  43+2  44+2
# 1217      200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...  ...  47+2  39+2
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...  ...   NaN   NaN
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...  ...   NaN   NaN
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...  ...   NaN   NaN
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...  ...   NaN   NaN
# 1217      200212  https://sofifa.com/player/200212/michael-esser...  ...   NaN   NaN
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...  ...  83+2  75+2
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...  ...   NaN   NaN
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...  ...  52+2  61+2
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...  ...  72+3  74+3
# 70      189596  https://sofifa.com/player/189596/thomas-muller...  ...  62+3  67+3
#
# [5 rows x 104 columns]

# %%
player_shooting= fifa[['short_name','shooting']]
player_shooting
# Out:
#               short_name  shooting
# 0               L. Messi      92.0
# 1      Cristiano Ronaldo      93.0
# 2              Neymar Jr      85.0
# 3               J. Oblak       NaN
# 4              E. Hazard      83.0
# ...                  ...       ...
# 18273         Shao Shuai      23.0
# 18274       Xiao Mingjie      24.0
# 18275          Zhang Wei      35.0
# 18276       Wang Haijian      35.0
# 18277         Pan Ximing      32.0
#
# [18278 rows x 2 columns]

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
player_defending= fifa[['short_name','defending','nationality','club']]
player_defending.head(50)
# Out:
#            short_name  defending     nationality                 club
# 0            L. Messi       39.0       Argentina         FC Barcelona
# 1   Cristiano Ronaldo       35.0        Portugal             Juventus
# 2           Neymar Jr       32.0          Brazil  Paris Saint-Germain
# 3            J. Oblak        NaN        Slovenia      Atlético Madrid
# 4           E. Hazard       35.0         Belgium          Real Madrid
# 5        K. De Bruyne       61.0         Belgium      Manchester City
# 6       M. ter Stegen        NaN         Germany         FC Barcelona
# 7         V. van Dijk       90.0     Netherlands            Liverpool
# 8           L. Modrić       72.0         Croatia          Real Madrid
# 9            M. Salah       45.0           Egypt            Liverpool
# 10          K. Mbappé       39.0          France  Paris Saint-Germain
# 11       K. Koulibaly       89.0         Senegal               Napoli
# ...

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
real_madrid=fifa[fifa['club']=='Real Madrid']
real_madrid
# Out:
#        sofifa_id                                         player_url  ...   rcb    rb
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 28        192119  https://sofifa.com/player/192119/thibaut-court...  ...   NaN   NaN
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...  ...  84+3  79+3
# 46        165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
# 53        193041  https://sofifa.com/player/193041/keylor-navas/...  ...   NaN   NaN
# 62        197781  https://sofifa.com/player/197781/francisco-rom...  ...  62+3  67+3
# 76        201535  https://sofifa.com/player/201535/raphael-varan...  ...  83+3  77+3
# ...

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 46     165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  ...   rcb    rb
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...  ...  49+3  61+3
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...  ...  72+3  79+3
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...  ...  69+3  72+3
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 46     165153  https://sofifa.com/player/165153/karim-benzema...  ...  54+3  58+3
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  ...   rcb    rb
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  82+3
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...  ...  84+3  79+3
# 76      201535  https://sofifa.com/player/201535/raphael-varan...  ...  83+3  77+3
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...  ...  80+3  83+3
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...  ...  79+2  78+2
#
# [5 rows x 104 columns]

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Japan                  1
# Dominican Republic     1
# Serbia                 1
# Costa Rica             1
# Colombia               1
# Uruguay                1
# Wales                  1
# Germany                1
# Name: nationality, dtype: int64

# %%
real_madrid['nationality'].head(10)
# Out:
# 4        Belgium
# 8        Croatia
# 18         Spain
# 28       Belgium
# 36       Germany
# 42        Brazil
# 46        France
# 53    Costa Rica
# 62         Spain
# 76        France
# Name: nationality, dtype: object

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color="gold")
plt.show()
